# %% [markdown]
# # Data Preprocessing for Covid19 Cases in Bangladesh Divisionwise
# Data preprocessing for creating analytical dashboard and ML model building
#
# ### Dataset - [Covid19 Cases in Bangladesh dataset](https://www.kaggle.com/datasets/rashikrahmanpritom/covid19-cases-in-bangladesh-dataset) From Kaggle
#
# ### Libraries
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Pathlib
# 6. Math

# %% [markdown]
# # Tasks
# - import modules
# - Read DataSet
# - Understanding Dataset
#     - Quick Overview
#     - Description
# - Sanity Check
#     - Standardizing Columns Name
#     - Proper Date Format for Visualization
#     - Data Type Handling
#     - Remove Duplicate
#     - Check Missing Values
# - Exploratory Data Analysis
#     - Histogram for Data Distribution
#     - Boxplot for Outliers Detection
#     - Scatterplot for Relationship between Variables
#         - Plot Confirmed Cases vs Deaths for each division
#         - Plot Case Rate vs Death Rate for each division
#         - Plot Confirmed Cases vs Case Rate for each division
#         - Plot Deaths vs Death Rate for each division
# - Handling Missing Values
#     - Fill missing value with 0
#     - Interpolation Methods
# - Handling Outliers
#     - IQR (Interquartile Range) method for columns with integer values (case and death counts)
#     - Z-Score method for float columns (rate columns).
# - Reshape Dataset for Visualization

# %% [markdown]
# ## Importing libraries

# %%
# Import libraries
from pathlib import Path
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
# create a Path object to represent the file path
filepath = Path("files/covid_dataset.csv")

covid = pd.read_csv(filepath)

# %% [markdown]
# ### Dataset loading confirmation

# %%
# check data
covid.head()
# Out:
#      Date  Confirmed cases Barisal  Case rate Barisal  Deaths Barisal  \
# 0  Mar-20                      NaN                NaN             NaN
# 1  Mar-20                      NaN                NaN             NaN
# 2  Mar-20                      NaN                NaN             NaN
# 3  Mar-20                      NaN                NaN             NaN
# 4  Mar-20                      NaN                NaN             NaN
#
#    Death Rate Barisal  Confirmed cases CTG  Case rate CTG  Deaths CTG  \
# 0                 NaN                  NaN            NaN         NaN
# 1                 NaN                  NaN            NaN         NaN
# 2                 NaN                  NaN            NaN         NaN
# 3                 NaN                  NaN            NaN         NaN
# 4                 NaN                  NaN            NaN         NaN
#
#    Death Rate CTG  Confirmed cases DHK  ...  Deaths Rangpur  \
# 0             NaN                  NaN  ...             NaN
# 1             NaN                  NaN  ...             NaN
# 2             NaN                  NaN  ...             NaN
# 3             NaN                  NaN  ...             NaN
# 4             NaN                  NaN  ...             NaN
#
#    Death Rate Rangpur  Confirmed cases Sylhet  Case rate Sylhet  \
# 0                 NaN                     NaN               NaN
# 1                 NaN                     NaN               NaN
# 2                 NaN                     NaN               NaN
# 3                 NaN                     NaN               NaN
# 4                 NaN                     NaN               NaN
#
#    Deaths Sylhet  Death Rate Sylhet  Confirmed cases allover Bangladesh  \
# 0            NaN                NaN                                 NaN
# 1            NaN                NaN                                 NaN
# 2            NaN                NaN                                 NaN
# 3            NaN                NaN                                 NaN
# 4            NaN                NaN                                 NaN
#
#    Case rate allover Bangladesh  Deaths allover Bangladesh  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
#
#    Death Rate allover Bangladesh
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 37 columns]

# %%
len(covid.columns)
# Out:
# 37

# %%
# data shape
print("Shape of the Covid19 Dataset:", covid.shape)
# Out:
# Shape of the Covid19 Dataset: (489, 37)

# %% [markdown]
# # Understand Dataset

# %%
# Overview of the dataset
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                489 non-null    object
#  1   Confirmed cases Barisal             447 non-null    float64
#  2   Case rate Barisal                   447 non-null    float64
#  3   Deaths Barisal                      461 non-null    float64
#  4   Death Rate Barisal                  461 non-null    float64
#  5   Confirmed cases CTG                 453 non-null    float64
#  6   Case rate CTG                       453 non-null    float64
#  7   Deaths CTG                          461 non-null    float64
#  8   Death Rate CTG                      461 non-null    float64
#  9   Confirmed cases DHK                 464 non-null    float64
#  10  Case rate DHK                       464 non-null    float64
#  11  Deaths DHK                          461 non-null    float64
#  12  Death Rate DHK                      461 non-null    float64
#  13  Confirmed cases Khulna              445 non-null    float64
#  14  Case rate Khulna                    445 non-null    float64
#  15  Deaths Khulna                       461 non-null    float64
#  16  Death Rate Khulna                   461 non-null    float64
#  17  Confirmed cases MMsingh             450 non-null    float64
#  18  Case rate MMsingh                   450 non-null    float64
#  19  Deaths MMsingh                      461 non-null    float64
#  20  Death Rate MMsingh                  461 non-null    float64
#  21  Confirmed cases Rajshahi            445 non-null    float64
#  22  Case rate Rajshahi                  445 non-null    float64
#  23  Deaths Rajshahi                     461 non-null    float64
#  24  Death Rate Rajshahi                 461 non-null    float64
#  25  Confirmed cases Rangpur             449 non-null    float64
#  26  Case rate Rangpur                   449 non-null    float64
#  27  Deaths Rangpur                      461 non-null    float64
#  28  Death Rate Rangpur                  461 non-null    float64
#  29  Confirmed cases Sylhet              452 non-null    float64
#  30  Case rate Sylhet                    452 non-null    float64
#  31  Deaths Sylhet                       461 non-null    float64
#  32  Death Rate Sylhet                   461 non-null    float64
#  33  Confirmed cases allover Bangladesh  456 non-null    float64
#  34  Case rate allover Bangladesh        456 non-null    float64
#  35  Deaths allover Bangladesh           461 non-null    float64
#  36  Death Rate allover Bangladesh       461 non-null    float64
# dtypes: float64(36), object(1)
# memory usage: 141.5+ KB

# %%
# dataset description
covid.describe(include='number').T
# Out:
#                                     count         mean          std  min  \
# Confirmed cases Barisal             447.0    45.785235    40.410211  1.0
# Case rate Barisal                   447.0    14.232662    10.911158  1.0
# Deaths Barisal                      461.0    32.056399    23.015332  1.0
# Death Rate Barisal                  461.0     2.173319     2.751546  0.0
# Confirmed cases CTG                 453.0   277.686534   222.340693  1.0
# Case rate CTG                       453.0    12.097130     9.533560  1.0
# Deaths CTG                          461.0    32.056399    23.015332  1.0
# Death Rate CTG                      461.0     2.173319     2.751546  0.0
# Confirmed cases DHK                 464.0   955.428879   870.037689  1.0
# Case rate DHK                       464.0    20.002155    15.986563  3.0
# Deaths DHK                          461.0    32.056399    23.015332  1.0
# Death Rate DHK                      461.0     2.173319     2.751546  0.0
# Confirmed cases Khulna              445.0   124.121348   169.910638  1.0
# Case rate Khulna                    445.0    17.238202    17.713228  0.0
# Deaths Khulna                       461.0    32.056399    23.015332  1.0
# Death Rate Khulna                   461.0     2.173319     2.751546  0.0
# Confirmed cases MMsingh             450.0    35.913333    37.183636  1.0
# Case rate MMsingh                   450.0    14.651111    20.220842  0.0
# Deaths MMsingh                      461.0    32.056399    23.015332  1.0
# Death Rate MMsingh                  461.0     2.173319     2.751546  0.0
# Confirmed cases Rajshahi            445.0   131.166292   138.626188  1.0
# Case rate Rajshahi                  445.0    15.150562    16.530269  1.0
# Deaths Rajshahi                     461.0    32.056399    23.015332  1.0
# Death Rate Rajshahi                 461.0     2.173319     2.751546  0.0
# Confirmed cases Rangpur             449.0    60.545657    72.583193  1.0
# Case rate Rangpur                   449.0    18.908686    18.336223  1.0
# Deaths Rangpur                      461.0    32.056399    23.015332  1.0
# Death Rate Rangpur                  461.0     2.173319     2.751546  0.0
# Confirmed cases Sylhet              452.0    59.360619    50.767594  1.0
# Case rate Sylhet                    452.0    13.022124    15.091133  0.0
# Deaths Sylhet                       461.0    32.056399    23.015332  1.0
# Death Rate Sylhet                   461.0     2.173319     2.751546  0.0
# Confirmed cases allover Bangladesh  456.0  2039.442982  1554.049917  5.0
# Case rate allover Bangladesh        456.0    13.372807     6.352748  2.0
# Deaths allover Bangladesh           461.0    32.056399    23.015332  1.0
# Death Rate allover Bangladesh       461.0     2.173319     2.751546  0.0
#
#                                         25%     50%      75%     max
# Confirmed cases Barisal               12.50    33.0    72.50   202.0
# Case rate Barisal                      6.00    11.0    21.00    73.0
# Deaths Barisal                        16.00    30.0    39.00   143.0
# Death Rate Barisal                     1.20     1.6     2.30    33.3
# Confirmed cases CTG                  122.00   214.0   383.00  1311.0
# Case rate CTG                          5.00     9.0    17.00    85.0
# Deaths CTG                            16.00    30.0    39.00   143.0
# Death Rate CTG                         1.20     1.6     2.30    33.3
# Confirmed cases DHK                  372.50   832.5  1192.75  5178.0
# Case rate DHK                         11.00    17.0    24.00   100.0
# Deaths DHK                            16.00    30.0    39.00   143.0
# Death Rate DHK                         1.20     1.6     2.30    33.3
# Confirmed cases Khulna                22.00    53.0   175.00  1116.0
# Case rate Khulna                       6.00    11.0    25.00   100.0
# Deaths Khulna                         16.00    30.0    39.00   143.0
# Death Rate Khulna                      1.20     1.6     2.30    33.3
# Confirmed cases MMsingh               13.00    25.0    47.00   281.0
# Case rate MMsingh                      5.25     9.0    14.00   100.0
# Deaths MMsingh                        16.00    30.0    39.00   143.0
# Death Rate MMsingh                     1.20     1.6     2.30    33.3
# Confirmed cases Rajshahi              39.00    86.0   184.00   913.0
# Case rate Rajshahi                     5.00    10.0    21.00   100.0
# Deaths Rajshahi                       16.00    30.0    39.00   143.0
# Death Rate Rajshahi                    1.20     1.6     2.30    33.3
# Confirmed cases Rangpur               18.00    42.0    75.00   724.0
# Case rate Rangpur                      9.00    14.0    23.00   100.0
# Deaths Rangpur                        16.00    30.0    39.00   143.0
# Death Rate Rangpur                     1.20     1.6     2.30    33.3
# Confirmed cases Sylhet                20.75    44.0    90.25   275.0
# Case rate Sylhet                       4.00     8.0    17.00   100.0
# Deaths Sylhet                         16.00    30.0    39.00   143.0
# Death Rate Sylhet                      1.20     1.6     2.30    33.3
# Confirmed cases allover Bangladesh  1012.25  1683.5  2715.00  8822.0
# Case rate allover Bangladesh           9.00    12.0    19.00    32.0
# Deaths allover Bangladesh             16.00    30.0    39.00   143.0
# Death Rate allover Bangladesh          1.20     1.6     2.30    33.3

# %% [markdown]
# # Sanity Check
# - Standardizing Columns Name
# - Proper Date Format for Visualization
# - Data Type Handling
# - Remove Duplicate
# - Check Missing Values

# %% [markdown]
# ## Column Name Standardization
#    - **TO DO:** Abbreviation to full name
#    - **TO DO:** Remove extra spaces
#    - **TO DO:** Make each word a title

# %%
# columns review
covid.columns
# Out:
# Index(['Date', 'Confirmed cases Barisal', 'Case rate Barisal',
#        'Deaths Barisal', 'Death Rate Barisal', 'Confirmed cases CTG',
#        'Case rate CTG', 'Deaths CTG', 'Death Rate CTG', 'Confirmed cases DHK',
#        'Case rate DHK', 'Deaths DHK', 'Death Rate DHK',
#        'Confirmed cases Khulna', 'Case rate Khulna', 'Deaths Khulna',
#        'Death Rate Khulna', 'Confirmed cases MMsingh', 'Case rate MMsingh',
#        'Deaths MMsingh', 'Death Rate MMsingh', 'Confirmed cases Rajshahi',
#        'Case rate Rajshahi', 'Deaths Rajshahi', 'Death Rate Rajshahi',
#        'Confirmed cases Rangpur', 'Case rate Rangpur', 'Deaths Rangpur',
#        'Death Rate Rangpur', 'Confirmed cases Sylhet', 'Case rate Sylhet',
#        'Deaths Sylhet', 'Death Rate Sylhet',
#        'Confirmed cases allover Bangladesh', 'Case rate allover Bangladesh',
#        'Deaths allover Bangladesh', 'Death Rate allover Bangladesh'],
#       dtype='object')

# %%
# Task: Standardize Column Names
# TO DO: Abbreviation to Full Form
# TO DO: Remove Exatra Spaces From Column Name
covid.columns = covid.columns.str.replace(r'CTG\b|DHK\b|MMsingh\b|\s{2, }', lambda x: {
                                             'CTG' : "Chittagong",
                                             'DHK' : "Dhaka",
                                             'MMsingh':  "Mymensingh",
                                             '\s{2, }': " "
                                         }[x.group()], regex=True).str.title()

# %%
# verify column names
covid.columns
# Out:
# Index(['Date', 'Confirmed Cases Barisal', 'Case Rate Barisal',
#        'Deaths Barisal', 'Death Rate Barisal', 'Confirmed Cases Chittagong',
#        'Case Rate Chittagong', 'Deaths Chittagong', 'Death Rate Chittagong',
#        'Confirmed Cases Dhaka', 'Case Rate Dhaka', 'Deaths Dhaka',
#        'Death Rate Dhaka', 'Confirmed Cases Khulna', 'Case Rate Khulna',
#        'Deaths Khulna', 'Death Rate Khulna', 'Confirmed Cases Mymensingh',
#        'Case Rate Mymensingh', 'Deaths Mymensingh', 'Death Rate Mymensingh',
#        'Confirmed Cases Rajshahi', 'Case Rate Rajshahi', 'Deaths Rajshahi',
#        'Death Rate Rajshahi', 'Confirmed Cases Rangpur', 'Case Rate Rangpur',
#        'Deaths Rangpur', 'Death Rate Rangpur', 'Confirmed Cases Sylhet',
#        'Case Rate Sylhet', 'Deaths Sylhet', 'Death Rate Sylhet',
#        'Confirmed Cases Allover Bangladesh', 'Case Rate Allover Bangladesh',
#        'Deaths Allover Bangladesh', 'Death Rate Allover Bangladesh'],
#       dtype='object')

# %% [markdown]
# ## Proper Date Format

# %%
# convert "Date" column to datetime
# TO DO : Parse month-year with a placeholder day (01)
# TO DO : Create sequential day number within each month-year group
# TO DO : Construct actual date by adding the offset
# TO DO : Remove the temporary columns


# parse month-year and store it in BaseDate column
covid['BaseDate'] = pd.to_datetime(covid['Date'].str.strip(), format='%b-%y', errors='coerce')

# create sequential day number within the month-year group and store it in DayOffset column
covid['DayOffset'] = covid.groupby('BaseDate').cumcount()

# Actual date by adading the date offset
covid['Date'] = covid['BaseDate'] + pd.to_timedelta(covid['DayOffset'], unit='D')

# drop temporary columns
covid.drop(columns=['BaseDate', 'DayOffset'], inplace=True)

# %%
# verify date column
covid['Date']
# Out:
# 0     2020-03-01
# 1     2020-03-02
# 2     2020-03-03
# 3     2020-03-04
# 4     2020-03-05
#          ...
# 484   2021-06-28
# 485   2021-06-29
# 486   2021-06-30
# 487   2021-07-01
# 488   2021-07-02
# Name: Date, Length: 489, dtype: datetime64[ns]

# %% [markdown]
# ## Data Type Handling

# %%
# quick overview of the dataset
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                489 non-null    datetime64[ns]
#  1   Confirmed Cases Barisal             447 non-null    float64
#  2   Case Rate Barisal                   447 non-null    float64
#  3   Deaths Barisal                      461 non-null    float64
#  4   Death Rate Barisal                  461 non-null    float64
#  5   Confirmed Cases Chittagong          453 non-null    float64
#  6   Case Rate Chittagong                453 non-null    float64
#  7   Deaths Chittagong                   461 non-null    float64
#  8   Death Rate Chittagong               461 non-null    float64
#  9   Confirmed Cases Dhaka               464 non-null    float64
#  10  Case Rate Dhaka                     464 non-null    float64
#  11  Deaths Dhaka                        461 non-null    float64
#  12  Death Rate Dhaka                    461 non-null    float64
#  13  Confirmed Cases Khulna              445 non-null    float64
#  14  Case Rate Khulna                    445 non-null    float64
#  15  Deaths Khulna                       461 non-null    float64
#  16  Death Rate Khulna                   461 non-null    float64
#  17  Confirmed Cases Mymensingh          450 non-null    float64
#  18  Case Rate Mymensingh                450 non-null    float64
#  19  Deaths Mymensingh                   461 non-null    float64
#  20  Death Rate Mymensingh               461 non-null    float64
#  21  Confirmed Cases Rajshahi            445 non-null    float64
#  22  Case Rate Rajshahi                  445 non-null    float64
#  23  Deaths Rajshahi                     461 non-null    float64
#  24  Death Rate Rajshahi                 461 non-null    float64
#  25  Confirmed Cases Rangpur             449 non-null    float64
#  26  Case Rate Rangpur                   449 non-null    float64
#  27  Deaths Rangpur                      461 non-null    float64
#  28  Death Rate Rangpur                  461 non-null    float64
#  29  Confirmed Cases Sylhet              452 non-null    float64
#  30  Case Rate Sylhet                    452 non-null    float64
#  31  Deaths Sylhet                       461 non-null    float64
#  32  Death Rate Sylhet                   461 non-null    float64
#  33  Confirmed Cases Allover Bangladesh  456 non-null    float64
#  34  Case Rate Allover Bangladesh        456 non-null    float64
#  35  Deaths Allover Bangladesh           461 non-null    float64
#  36  Death Rate Allover Bangladesh       461 non-null    float64
# dtypes: datetime64[ns](1), float64(36)
# memory usage: 141.5 KB

# %%
# function to fix data type of the columns
def fix_dtype(col_name, series):
    if "Rate" in col_name or col_name == covid.columns[0]:
        return series
    else:
        return pd.to_numeric(series, errors='coerce').astype('Int64')

# %%
# verify and change column dtype
for col in covid.columns:
    covid[col] = fix_dtype(col, covid[col])

# %% [markdown]
# **NOTE:** NaN is a float, and pandas cannot convert NaN to int64, hence a ValueError will raise. Either we can change the data type after converting the NaN to Numeric values or use Int64 (with capital I) — the pandas nullable integer type that supports NaN

# %%
# verify data types
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                489 non-null    datetime64[ns]
#  1   Confirmed Cases Barisal             447 non-null    Int64
#  2   Case Rate Barisal                   447 non-null    float64
#  3   Deaths Barisal                      461 non-null    Int64
#  4   Death Rate Barisal                  461 non-null    float64
#  5   Confirmed Cases Chittagong          453 non-null    Int64
#  6   Case Rate Chittagong                453 non-null    float64
#  7   Deaths Chittagong                   461 non-null    Int64
#  8   Death Rate Chittagong               461 non-null    float64
#  9   Confirmed Cases Dhaka               464 non-null    Int64
#  10  Case Rate Dhaka                     464 non-null    float64
#  11  Deaths Dhaka                        461 non-null    Int64
#  12  Death Rate Dhaka                    461 non-null    float64
#  13  Confirmed Cases Khulna              445 non-null    Int64
#  14  Case Rate Khulna                    445 non-null    float64
#  15  Deaths Khulna                       461 non-null    Int64
#  16  Death Rate Khulna                   461 non-null    float64
#  17  Confirmed Cases Mymensingh          450 non-null    Int64
#  18  Case Rate Mymensingh                450 non-null    float64
#  19  Deaths Mymensingh                   461 non-null    Int64
#  20  Death Rate Mymensingh               461 non-null    float64
#  21  Confirmed Cases Rajshahi            445 non-null    Int64
#  22  Case Rate Rajshahi                  445 non-null    float64
#  23  Deaths Rajshahi                     461 non-null    Int64
#  24  Death Rate Rajshahi                 461 non-null    float64
#  25  Confirmed Cases Rangpur             449 non-null    Int64
#  26  Case Rate Rangpur                   449 non-null    float64
#  27  Deaths Rangpur                      461 non-null    Int64
#  28  Death Rate Rangpur                  461 non-null    float64
#  29  Confirmed Cases Sylhet              452 non-null    Int64
#  30  Case Rate Sylhet                    452 non-null    float64
#  31  Deaths Sylhet                       461 non-null    Int64
#  32  Death Rate Sylhet                   461 non-null    float64
#  33  Confirmed Cases Allover Bangladesh  456 non-null    Int64
#  34  Case Rate Allover Bangladesh        456 non-null    float64
#  35  Deaths Allover Bangladesh           461 non-null    Int64
#  36  Death Rate Allover Bangladesh       461 non-null    float64
# dtypes: Int64(18), datetime64[ns](1), float64(18)
# memory usage: 150.1 KB

# %% [markdown]
# ## Remove Duplicates
#    - **TO DO** : Check Duplicate Rows
#    - **TO DO** : Duplicate Count
#    - **TO DO** : Drop Duplicates (If Any)

# %%
# duplicate rows
covid.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 484    False
# 485    False
# 486    False
# 487    False
# 488    False
# Length: 489, dtype: bool

# %%
# duplicates count
covid.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Missing Values

# %%
# checking columns that has NaN values
covid.isnull().sum()
# Out:
# Date                                   0
# Confirmed Cases Barisal               42
# Case Rate Barisal                     42
# Deaths Barisal                        28
# Death Rate Barisal                    28
# Confirmed Cases Chittagong            36
# Case Rate Chittagong                  36
# Deaths Chittagong                     28
# Death Rate Chittagong                 28
# Confirmed Cases Dhaka                 25
# Case Rate Dhaka                       25
# Deaths Dhaka                          28
# Death Rate Dhaka                      28
# Confirmed Cases Khulna                44
# Case Rate Khulna                      44
# Deaths Khulna                         28
# Death Rate Khulna                     28
# Confirmed Cases Mymensingh            39
# Case Rate Mymensingh                  39
# Deaths Mymensingh                     28
# Death Rate Mymensingh                 28
# Confirmed Cases Rajshahi              44
# Case Rate Rajshahi                    44
# Deaths Rajshahi                       28
# Death Rate Rajshahi                   28
# Confirmed Cases Rangpur               40
# Case Rate Rangpur                     40
# Deaths Rangpur                        28
# Death Rate Rangpur                    28
# Confirmed Cases Sylhet                37
# Case Rate Sylhet                      37
# Deaths Sylhet                         28
# Death Rate Sylhet                     28
# Confirmed Cases Allover Bangladesh    33
# Case Rate Allover Bangladesh          33
# Deaths Allover Bangladesh             28
# Death Rate Allover Bangladesh         28
# dtype: int64

# %%
# missing value percentage
covid.isnull().sum() / covid.shape[0] * 100
# Out:
# Date                                  0.000000
# Confirmed Cases Barisal               8.588957
# Case Rate Barisal                     8.588957
# Deaths Barisal                        5.725971
# Death Rate Barisal                    5.725971
# Confirmed Cases Chittagong            7.361963
# Case Rate Chittagong                  7.361963
# Deaths Chittagong                     5.725971
# Death Rate Chittagong                 5.725971
# Confirmed Cases Dhaka                 5.112474
# Case Rate Dhaka                       5.112474
# Deaths Dhaka                          5.725971
# Death Rate Dhaka                      5.725971
# Confirmed Cases Khulna                8.997955
# Case Rate Khulna                      8.997955
# Deaths Khulna                         5.725971
# Death Rate Khulna                     5.725971
# Confirmed Cases Mymensingh            7.975460
# Case Rate Mymensingh                  7.975460
# Deaths Mymensingh                     5.725971
# Death Rate Mymensingh                 5.725971
# Confirmed Cases Rajshahi              8.997955
# Case Rate Rajshahi                    8.997955
# Deaths Rajshahi                       5.725971
# Death Rate Rajshahi                   5.725971
# Confirmed Cases Rangpur               8.179959
# Case Rate Rangpur                     8.179959
# Deaths Rangpur                        5.725971
# Death Rate Rangpur                    5.725971
# Confirmed Cases Sylhet                7.566462
# Case Rate Sylhet                      7.566462
# Deaths Sylhet                         5.725971
# Death Rate Sylhet                     5.725971
# Confirmed Cases Allover Bangladesh    6.748466
# Case Rate Allover Bangladesh          6.748466
# Deaths Allover Bangladesh             5.725971
# Death Rate Allover Bangladesh         5.725971
# dtype: float64

# %%
# Filtering Not NaN rows
# returns True for rows where at least one non-date column is not NaN.
covid[covid.drop(columns='Date').notna().any(axis=1)].head()
# Out:
#          Date  Confirmed Cases Barisal  Case Rate Barisal  Deaths Barisal  \
# 5  2020-03-06                        1                7.0            <NA>
# 7  2020-03-08                        1               13.0            <NA>
# 8  2020-03-09                     <NA>                NaN            <NA>
# 17 2020-03-18                     <NA>                NaN               1
# 18 2020-03-19                     <NA>                NaN            <NA>
#
#     Death Rate Barisal  Confirmed Cases Chittagong  Case Rate Chittagong  \
# 5                  NaN                        <NA>                   NaN
# 7                  NaN                           1                  50.0
# 8                  NaN                           2                  33.0
# 17                25.0                        <NA>                   NaN
# 18                 NaN                        <NA>                   NaN
#
#     Deaths Chittagong  Death Rate Chittagong  Confirmed Cases Dhaka  ...  \
# 5                <NA>                    NaN                      3  ...
# 7                <NA>                    NaN                     55  ...
# 8                <NA>                    NaN                   <NA>  ...
# 17                  1                   25.0                   <NA>  ...
# 18               <NA>                    NaN                      1  ...
#
#     Deaths Rangpur  Death Rate Rangpur  Confirmed Cases Sylhet  \
# 5             <NA>                 NaN                    <NA>
# 7             <NA>                 NaN                    <NA>
# 8             <NA>                 NaN                    <NA>
# 17               1                25.0                    <NA>
# 18            <NA>                 NaN                    <NA>
#
#     Case Rate Sylhet  Deaths Sylhet  Death Rate Sylhet  \
# 5                NaN           <NA>                NaN
# 7                NaN           <NA>                NaN
# 8                NaN           <NA>                NaN
# 17               NaN              1               25.0
# 18               NaN           <NA>                NaN
#
#     Confirmed Cases Allover Bangladesh  Case Rate Allover Bangladesh  \
# 5                                 <NA>                           NaN
# 7                                 <NA>                           NaN
# 8                                 <NA>                           NaN
# 17                                <NA>                           NaN
# 18                                <NA>                           NaN
#
#     Deaths Allover Bangladesh  Death Rate Allover Bangladesh
# 5                        <NA>                            NaN
# 7                        <NA>                            NaN
# 8                        <NA>                            NaN
# 17                          1                           25.0
# 18                       <NA>                            NaN
#
# [5 rows x 37 columns]

# %%
# getting rows that have at least one not NaN value
covid = covid[covid.drop(columns='Date').notna().any(axis=1)]

# %%
# reset index
covid.reset_index(drop=True, inplace=True)

# %%
covid.head()
# Out:
#         Date  Confirmed Cases Barisal  Case Rate Barisal  Deaths Barisal  \
# 0 2020-03-06                        1                7.0            <NA>
# 1 2020-03-08                        1               13.0            <NA>
# 2 2020-03-09                     <NA>                NaN            <NA>
# 3 2020-03-18                     <NA>                NaN               1
# 4 2020-03-19                     <NA>                NaN            <NA>
#
#    Death Rate Barisal  Confirmed Cases Chittagong  Case Rate Chittagong  \
# 0                 NaN                        <NA>                   NaN
# 1                 NaN                           1                  50.0
# 2                 NaN                           2                  33.0
# 3                25.0                        <NA>                   NaN
# 4                 NaN                        <NA>                   NaN
#
#    Deaths Chittagong  Death Rate Chittagong  Confirmed Cases Dhaka  ...  \
# 0               <NA>                    NaN                      3  ...
# 1               <NA>                    NaN                     55  ...
# 2               <NA>                    NaN                   <NA>  ...
# 3                  1                   25.0                   <NA>  ...
# 4               <NA>                    NaN                      1  ...
#
#    Deaths Rangpur  Death Rate Rangpur  Confirmed Cases Sylhet  \
# 0            <NA>                 NaN                    <NA>
# 1            <NA>                 NaN                    <NA>
# 2            <NA>                 NaN                    <NA>
# 3               1                25.0                    <NA>
# 4            <NA>                 NaN                    <NA>
#
#    Case Rate Sylhet  Deaths Sylhet  Death Rate Sylhet  \
# 0               NaN           <NA>                NaN
# 1               NaN           <NA>                NaN
# 2               NaN           <NA>                NaN
# 3               NaN              1               25.0
# 4               NaN           <NA>                NaN
#
#    Confirmed Cases Allover Bangladesh  Case Rate Allover Bangladesh  \
# 0                                <NA>                           NaN
# 1                                <NA>                           NaN
# 2                                <NA>                           NaN
# 3                                <NA>                           NaN
# 4                                <NA>                           NaN
#
#    Deaths Allover Bangladesh  Death Rate Allover Bangladesh
# 0                       <NA>                            NaN
# 1                       <NA>                            NaN
# 2                       <NA>                            NaN
# 3                          1                           25.0
# 4                       <NA>                            NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# - Histogram for Data Distribution
# - Boxplot for Outliers Detection
# - Scatterplot for Relationship between Variables

# %%
# Description of the dataset
covid.describe().T
# Out:
#                                     count                           mean  \
# Date                                  471  2020-11-08 19:58:28.280254720
# Confirmed Cases Barisal             447.0                      45.785235
# Case Rate Barisal                   447.0                      14.232662
# Deaths Barisal                      461.0                      32.056399
# Death Rate Barisal                  461.0                       2.173319
# Confirmed Cases Chittagong          453.0                     277.686534
# Case Rate Chittagong                453.0                       12.09713
# Deaths Chittagong                   461.0                      32.056399
# Death Rate Chittagong               461.0                       2.173319
# Confirmed Cases Dhaka               464.0                     955.428879
# Case Rate Dhaka                     464.0                      20.002155
# Deaths Dhaka                        461.0                      32.056399
# Death Rate Dhaka                    461.0                       2.173319
# Confirmed Cases Khulna              445.0                     124.121348
# Case Rate Khulna                    445.0                      17.238202
# Deaths Khulna                       461.0                      32.056399
# Death Rate Khulna                   461.0                       2.173319
# Confirmed Cases Mymensingh          450.0                      35.913333
# Case Rate Mymensingh                450.0                      14.651111
# Deaths Mymensingh                   461.0                      32.056399
# Death Rate Mymensingh               461.0                       2.173319
# Confirmed Cases Rajshahi            445.0                     131.166292
# Case Rate Rajshahi                  445.0                      15.150562
# Deaths Rajshahi                     461.0                      32.056399
# Death Rate Rajshahi                 461.0                       2.173319
# Confirmed Cases Rangpur             449.0                      60.545657
# Case Rate Rangpur                   449.0                      18.908686
# Deaths Rangpur                      461.0                      32.056399
# Death Rate Rangpur                  461.0                       2.173319
# Confirmed Cases Sylhet              452.0                      59.360619
# Case Rate Sylhet                    452.0                      13.022124
# Deaths Sylhet                       461.0                      32.056399
# Death Rate Sylhet                   461.0                       2.173319
# Confirmed Cases Allover Bangladesh  456.0                    2039.442982
# Case Rate Allover Bangladesh        456.0                      13.372807
# Deaths Allover Bangladesh           461.0                      32.056399
# Death Rate Allover Bangladesh       461.0                       2.173319
#
#                                                     min                  25%  \
# Date                                2020-03-06 00:00:00  2020-07-14 12:00:00
# Confirmed Cases Barisal                             1.0                 12.5
# Case Rate Barisal                                   1.0                  6.0
# Deaths Barisal                                      1.0                 16.0
# Death Rate Barisal                                  0.0                  1.2
# Confirmed Cases Chittagong                          1.0                122.0
# Case Rate Chittagong                                1.0                  5.0
# Deaths Chittagong                                   1.0                 16.0
# Death Rate Chittagong                               0.0                  1.2
# Confirmed Cases Dhaka                               1.0                372.5
# Case Rate Dhaka                                     3.0                 11.0
# Deaths Dhaka                                        1.0                 16.0
# Death Rate Dhaka                                    0.0                  1.2
# Confirmed Cases Khulna                              1.0                 22.0
# Case Rate Khulna                                    0.0                  6.0
# Deaths Khulna                                       1.0                 16.0
# Death Rate Khulna                                   0.0                  1.2
# Confirmed Cases Mymensingh                          1.0                 13.0
# Case Rate Mymensingh                                0.0                 5.25
# Deaths Mymensingh                                   1.0                 16.0
# Death Rate Mymensingh                               0.0                  1.2
# Confirmed Cases Rajshahi                            1.0                 39.0
# Case Rate Rajshahi                                  1.0                  5.0
# Deaths Rajshahi                                     1.0                 16.0
# Death Rate Rajshahi                                 0.0                  1.2
# Confirmed Cases Rangpur                             1.0                 18.0
# Case Rate Rangpur                                   1.0                  9.0
# Deaths Rangpur                                      1.0                 16.0
# Death Rate Rangpur                                  0.0                  1.2
# Confirmed Cases Sylhet                              1.0                20.75
# Case Rate Sylhet                                    0.0                  4.0
# Deaths Sylhet                                       1.0                 16.0
# Death Rate Sylhet                                   0.0                  1.2
# Confirmed Cases Allover Bangladesh                  5.0              1012.25
# Case Rate Allover Bangladesh                        2.0                  9.0
# Deaths Allover Bangladesh                           1.0                 16.0
# Death Rate Allover Bangladesh                       0.0                  1.2
#
#                                                     50%                  75%  \
# Date                                2020-11-09 00:00:00  2021-03-06 12:00:00
# Confirmed Cases Barisal                            33.0                 72.5
# Case Rate Barisal                                  11.0                 21.0
# Deaths Barisal                                     30.0                 39.0
# Death Rate Barisal                                  1.6                  2.3
# Confirmed Cases Chittagong                        214.0                383.0
# Case Rate Chittagong                                9.0                 17.0
# Deaths Chittagong                                  30.0                 39.0
# Death Rate Chittagong                               1.6                  2.3
# Confirmed Cases Dhaka                             832.5              1192.75
# Case Rate Dhaka                                    17.0                 24.0
# Deaths Dhaka                                       30.0                 39.0
# Death Rate Dhaka                                    1.6                  2.3
# Confirmed Cases Khulna                             53.0                175.0
# Case Rate Khulna                                   11.0                 25.0
# Deaths Khulna                                      30.0                 39.0
# Death Rate Khulna                                   1.6                  2.3
# Confirmed Cases Mymensingh                         25.0                 47.0
# Case Rate Mymensingh                                9.0                 14.0
# Deaths Mymensingh                                  30.0                 39.0
# Death Rate Mymensingh                               1.6                  2.3
# Confirmed Cases Rajshahi                           86.0                184.0
# Case Rate Rajshahi                                 10.0                 21.0
# Deaths Rajshahi                                    30.0                 39.0
# Death Rate Rajshahi                                 1.6                  2.3
# Confirmed Cases Rangpur                            42.0                 75.0
# Case Rate Rangpur                                  14.0                 23.0
# Deaths Rangpur                                     30.0                 39.0
# Death Rate Rangpur                                  1.6                  2.3
# Confirmed Cases Sylhet                             44.0                90.25
# Case Rate Sylhet                                    8.0                 17.0
# Deaths Sylhet                                      30.0                 39.0
# Death Rate Sylhet                                   1.6                  2.3
# Confirmed Cases Allover Bangladesh               1683.5               2715.0
# Case Rate Allover Bangladesh                       12.0                 19.0
# Deaths Allover Bangladesh                          30.0                 39.0
# Death Rate Allover Bangladesh                       1.6                  2.3
#
#                                                     max          std
# Date                                2021-07-02 00:00:00          NaN
# Confirmed Cases Barisal                           202.0    40.410211
# Case Rate Barisal                                  73.0    10.911158
# Deaths Barisal                                    143.0    23.015332
# Death Rate Barisal                                 33.3     2.751546
# Confirmed Cases Chittagong                       1311.0   222.340693
# Case Rate Chittagong                               85.0      9.53356
# Deaths Chittagong                                 143.0    23.015332
# Death Rate Chittagong                              33.3     2.751546
# Confirmed Cases Dhaka                            5178.0   870.037689
# Case Rate Dhaka                                   100.0    15.986563
# Deaths Dhaka                                      143.0    23.015332
# Death Rate Dhaka                                   33.3     2.751546
# Confirmed Cases Khulna                           1116.0   169.910638
# Case Rate Khulna                                  100.0    17.713228
# Deaths Khulna                                     143.0    23.015332
# Death Rate Khulna                                  33.3     2.751546
# Confirmed Cases Mymensingh                        281.0    37.183636
# Case Rate Mymensingh                              100.0    20.220842
# Deaths Mymensingh                                 143.0    23.015332
# Death Rate Mymensingh                              33.3     2.751546
# Confirmed Cases Rajshahi                          913.0   138.626188
# Case Rate Rajshahi                                100.0    16.530269
# Deaths Rajshahi                                   143.0    23.015332
# Death Rate Rajshahi                                33.3     2.751546
# Confirmed Cases Rangpur                           724.0    72.583193
# Case Rate Rangpur                                 100.0    18.336223
# Deaths Rangpur                                    143.0    23.015332
# Death Rate Rangpur                                 33.3     2.751546
# Confirmed Cases Sylhet                            275.0    50.767594
# Case Rate Sylhet                                  100.0    15.091133
# Deaths Sylhet                                     143.0    23.015332
# Death Rate Sylhet                                  33.3     2.751546
# Confirmed Cases Allover Bangladesh               8822.0  1554.049917
# Case Rate Allover Bangladesh                       32.0     6.352748
# Deaths Allover Bangladesh                         143.0    23.015332
# Death Rate Allover Bangladesh                      33.3     2.751546

# %% [markdown]
# ## figure size

# %%
plt.figure(figsize=(10, 6))
plt.show()

# %% [markdown]
# ## Histogram for Data Disribution

# %%
""" histogram for all columns at a single place for quick overview """

# set the number of rows and columns for the grid
rows, cols = 9, 4

# create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
fig.tight_layout(pad=5.0)
fig.suptitle('Histogram for Data Distribution', fontsize=15, y=1.01)

# loop through each column and plot on a different subplot
for i, col in enumerate(covid.select_dtypes(include="number").columns):
    row_pos = i // cols
    col_pos = i % cols
    sns.histplot(data=covid, x=col, ax=axes[row_pos, col_pos])

# remove any empty subplots
for j in range(i+1, rows*cols):
    fig.delaxes(axes[j // cols, j % cols])

plt.show()

# %% [markdown]
# ## Boxplot for Outliers Detection

# %%
""" boxplot for all columns at a single place for quick overview """

# set the number of rows and columns for the grid
rows, cols = 9, 4

# create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
fig.tight_layout(pad=3.0)
fig.suptitle('Boxplot to check the outliers', fontsize=15, y=1.01)

# loop through each column and plot on a different subplot
for i, col in enumerate(covid.select_dtypes(include="number").columns):
    row_pos = i // cols
    col_pos = i % cols
    sns.boxplot(data=covid, x=col, ax=axes[row_pos, col_pos])
#     axes[row_pos, col_pos].set_title(col)

# remove any empty subplots
for j in range(i+1, rows*cols):
    fig.delaxes(axes[j // cols, j % cols])

plt.show()

# %% [markdown]
# ## Scatter to identify relationships between two numerical variables
# 1. Plot Confirmed Cases vs Deaths for each division
# 2. Plot Case Rate vs Death Rate for each division
# 3. Plot Confirmed Cases vs Case Rate for each division
# 4. Plot Deaths vs Death Rate for each division

# %%
# split columns into two categories
confirmed_cases = [col for col in covid.columns if col.startswith("Confirmed Cases")]
deaths = [col for col in covid.columns if col.startswith("Deaths") and not col.startswith("Death Rate")]
death_rates = [col for col in covid.columns if col.startswith("Death Rate")]
case_rates = [col for col in covid.columns if col.startswith("Case Rate")]

# %%
print("Confirmed Cases:", confirmed_cases)
print("Deaths:", deaths)
print("Death Rates:", death_rates)
print("Case Rates:", case_rates)
# Out:
# Confirmed Cases: ['Confirmed Cases Barisal', 'Confirmed Cases Chittagong', 'Confirmed Cases Dhaka', 'Confirmed Cases Khulna', 'Confirmed Cases Mymensingh', 'Confirmed Cases Rajshahi', 'Confirmed Cases Rangpur', 'Confirmed Cases Sylhet', 'Confirmed Cases Allover Bangladesh']
# Deaths: ['Deaths Barisal', 'Deaths Chittagong', 'Deaths Dhaka', 'Deaths Khulna', 'Deaths Mymensingh', 'Deaths Rajshahi', 'Deaths Rangpur', 'Deaths Sylhet', 'Deaths Allover Bangladesh']
# Death Rates: ['Death Rate Barisal', 'Death Rate Chittagong', 'Death Rate Dhaka', 'Death Rate Khulna', 'Death Rate Mymensingh', 'Death Rate Rajshahi', 'Death Rate Rangpur', 'Death Rate Sylhet', 'Death Rate Allover Bangladesh']
# Case Rates: ['Case Rate Barisal', 'Case Rate Chittagong', 'Case Rate Dhaka', 'Case Rate Khulna', 'Case Rate Mymensingh', 'Case Rate Rajshahi', 'Case Rate Rangpur', 'Case Rate Sylhet', 'Case Rate Allover Bangladesh']

# %% [markdown]
# ### Relationship Between Confirmed Case and Deaths

# %%
# Determine number of plots
n_plots = len(confirmed_cases)
cols = 3
rows = math.ceil(n_plots / cols)

# Create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
axes = axes.flatten()  # Make axes a 1D array for easy indexing
fig.tight_layout(pad=5.0)
fig.suptitle('Confirmed Cases vs Deaths', fontsize=18, y=1.03)

# Plot each pair
for i, (confirm, death) in enumerate(zip(confirmed_cases, deaths)):
    sns.scatterplot(data=covid, x=confirm, y=death, ax=axes[i])
    axes[i].set_title(f"{confirm} vs {death}")

# Hide unused subplots
for j in range(n_plots, len(axes)):
    fig.delaxes(axes[j])

plt.show()

# %% [markdown]
# ### Relationship Betweeen Case Rates and Death Rates

# %%
# Determine number of plots
n_plots = len(case_rates)
cols = 3
rows = math.ceil(n_plots / cols)

# Create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
axes = axes.flatten()  # Make axes a 1D array for easy indexing
fig.tight_layout(pad=5.0)
fig.suptitle('Case Rate vs Deaths Rate', fontsize=18, y=1.03)

# Plot each pair
for i, (case, death) in enumerate(zip(case_rates, death_rates)):
    sns.scatterplot(data=covid, x=case, y=death, ax=axes[i])
    axes[i].set_title(f"{case} vs {death}")

# Hide unused subplots
for j in range(n_plots, len(axes)):
    fig.delaxes(axes[j])

plt.show()

# %% [markdown]
# ### Relationship Between Confirmed Cases and Case Rate

# %%
# Determine number of plots
n_plots = len(confirmed_cases)
cols = 3
rows = math.ceil(n_plots / cols)

# Create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
axes = axes.flatten()  # Make axes a 1D array for easy indexing
fig.tight_layout(pad=5.0)
fig.suptitle('Confirmed Cases vs Case Rate', fontsize=18, y=1.03)

# Plot each pair
for i, (confirm, case) in enumerate(zip(confirmed_cases, case_rates)):
    sns.scatterplot(data=covid, x=confirm, y=case, ax=axes[i])
    axes[i].set_title(f"{confirm} vs {case}")

# Hide unused subplots
for j in range(n_plots, len(axes)):
    fig.delaxes(axes[j])

plt.show()

# %% [markdown]
# ### Relationship Between Deaths Cases and Deaths Rate

# %%
# Determine number of plots
n_plots = len(deaths)
cols = 3
rows = math.ceil(n_plots / cols)

# Create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
axes = axes.flatten()  # Make axes a 1D array for easy indexing
fig.tight_layout(pad=5.0)
fig.suptitle('Deaths Cases vs Deaths Rate', fontsize=18, y=1.03)

# Plot each pair
for i, (cases, rate) in enumerate(zip(deaths, death_rates)):
    sns.scatterplot(data=covid, x=cases, y=rate, ax=axes[i])
    axes[i].set_title(f"{cases} vs {rate}")

# Hide unused subplots
for j in range(n_plots, len(axes)):
    fig.delaxes(axes[j])

plt.show()

# %% [markdown]
# ## Handling Missing Value

# %% [markdown]
# ### Observation (According to Histogram)
# 1. Most columns are right-skewed, meaning the majority of the data is concentrated toward the lower end (left side), and there's a long tail to the right.
# 2. In many histograms, there's a large spike at 0, which likely reflects your NaN-filled-with-zero strategy.
# 3. Some histograms show discrete steps, indicating categorical-like or integer-discrete data.
#
# ### Decision
# If the missing values truly represent the absence of cases or deaths (indicates case recorded), we can fill the missing values with 0. But filling missing values with 0 will distorts the analysis if the column indicates the ratio / rate.
#
# ### Action
# - fill columns like Confirmed cases or Deaths, where 0 = no event.
# - Use interpolation for smoother trends in rate columns (Case rate, Death rate).

# %%
# Interpolate missing values for numeric columns
# Fill NaN values in "Rate" columns with linear interpolation
for col in covid.columns:
    if col == "Date":
        continue                                                        # Skip the "Date" column

    elif "Rate" in col:
        covid[col] = covid[col].interpolate(method='linear')            # Check if the column is numeric and contains "Rate"
    
    else:
        covid[col] = covid[col].fillna(0)                               # For other numeric columns, fill NaN with 0

# %%
# checking missing value imputation
covid.isnull().any()
# Out:
# Date                                  False
# Confirmed Cases Barisal               False
# Case Rate Barisal                     False
# Deaths Barisal                        False
# Death Rate Barisal                     True
# Confirmed Cases Chittagong            False
# Case Rate Chittagong                   True
# Deaths Chittagong                     False
# Death Rate Chittagong                  True
# Confirmed Cases Dhaka                 False
# Case Rate Dhaka                       False
# Deaths Dhaka                          False
# Death Rate Dhaka                       True
# Confirmed Cases Khulna                False
# Case Rate Khulna                       True
# Deaths Khulna                         False
# Death Rate Khulna                      True
# Confirmed Cases Mymensingh            False
# Case Rate Mymensingh                   True
# Deaths Mymensingh                     False
# Death Rate Mymensingh                  True
# Confirmed Cases Rajshahi              False
# Case Rate Rajshahi                     True
# Deaths Rajshahi                       False
# Death Rate Rajshahi                    True
# Confirmed Cases Rangpur               False
# Case Rate Rangpur                      True
# Deaths Rangpur                        False
# Death Rate Rangpur                     True
# Confirmed Cases Sylhet                False
# Case Rate Sylhet                       True
# Deaths Sylhet                         False
# Death Rate Sylhet                      True
# Confirmed Cases Allover Bangladesh    False
# Case Rate Allover Bangladesh           True
# Deaths Allover Bangladesh             False
# Death Rate Allover Bangladesh          True
# dtype: bool

# %%
covid.isnull().sum()
# Out:
# Date                                   0
# Confirmed Cases Barisal                0
# Case Rate Barisal                      0
# Deaths Barisal                         0
# Death Rate Barisal                     3
# Confirmed Cases Chittagong             0
# Case Rate Chittagong                   1
# Deaths Chittagong                      0
# Death Rate Chittagong                  3
# Confirmed Cases Dhaka                  0
# Case Rate Dhaka                        0
# Deaths Dhaka                           0
# Death Rate Dhaka                       3
# Confirmed Cases Khulna                 0
# Case Rate Khulna                      22
# Deaths Khulna                          0
# Death Rate Khulna                      3
# Confirmed Cases Mymensingh             0
# Case Rate Mymensingh                  17
# Deaths Mymensingh                      0
# Death Rate Mymensingh                  3
# Confirmed Cases Rajshahi               0
# Case Rate Rajshahi                     1
# Deaths Rajshahi                        0
# Death Rate Rajshahi                    3
# Confirmed Cases Rangpur                0
# Case Rate Rangpur                     12
# Deaths Rangpur                         0
# Death Rate Rangpur                     3
# Confirmed Cases Sylhet                 0
# Case Rate Sylhet                      14
# Deaths Sylhet                          0
# Death Rate Sylhet                      3
# Confirmed Cases Allover Bangladesh     0
# Case Rate Allover Bangladesh          15
# Deaths Allover Bangladesh              0
# Death Rate Allover Bangladesh          3
# dtype: int64

# %%
covid.head()
# Out:
#         Date  Confirmed Cases Barisal  Case Rate Barisal  Deaths Barisal  \
# 0 2020-03-06                        1           7.000000               0
# 1 2020-03-08                        1          13.000000               0
# 2 2020-03-09                        0          13.631579               0
# 3 2020-03-18                        0          14.263158               1
# 4 2020-03-19                        0          14.894737               0
#
#    Death Rate Barisal  Confirmed Cases Chittagong  Case Rate Chittagong  \
# 0                 NaN                           0                   NaN
# 1                 NaN                           1             50.000000
# 2                 NaN                           2             33.000000
# 3                25.0                           0             31.470588
# 4                25.0                           0             29.941176
#
#    Deaths Chittagong  Death Rate Chittagong  Confirmed Cases Dhaka  ...  \
# 0                  0                    NaN                      3  ...
# 1                  0                    NaN                     55  ...
# 2                  0                    NaN                      0  ...
# 3                  1                   25.0                      0  ...
# 4                  0                   25.0                      1  ...
#
#    Deaths Rangpur  Death Rate Rangpur  Confirmed Cases Sylhet  \
# 0               0                 NaN                       0
# 1               0                 NaN                       0
# 2               0                 NaN                       0
# 3               1                25.0                       0
# 4               0                25.0                       0
#
#    Case Rate Sylhet  Deaths Sylhet  Death Rate Sylhet  \
# 0               NaN              0                NaN
# 1               NaN              0                NaN
# 2               NaN              0                NaN
# 3               NaN              1               25.0
# 4               NaN              0               25.0
#
#    Confirmed Cases Allover Bangladesh  Case Rate Allover Bangladesh  \
# 0                                   0                           NaN
# 1                                   0                           NaN
# 2                                   0                           NaN
# 3                                   0                           NaN
# 4                                   0                           NaN
#
#    Deaths Allover Bangladesh  Death Rate Allover Bangladesh
# 0                          0                            NaN
# 1                          0                            NaN
# 2                          0                            NaN
# 3                          1                           25.0
# 4                          0                           25.0
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Outliers Treatment

# %% [markdown]
# ### Observation
# 1. Almost all "Confirmed Cases" and "Deaths" columns across divisions show:
#     - High number of outliers
#     - Right-skewed distribution (Median near bottom, long upper whisker)
#     - Some features with extremely large spikes
# 2. Death Rate and Case Rate columns also contain:
#     - Moderate to high outliers
#     - Some variation among divisions
#
# ### Decision
# When data contains valuable but extreme values, extreme outliers can be replaced with Capping (Winsorization). upper/lower bounds (Q1 - 1.5×IQR or Q3 + 1.5×IQR)
#
# ### Action
# - IQR (Interquartile Range) method for columns with integer values (case and death counts)
# - Z-Score method for float columns (rate columns).

# %%
# implement function for IQR method
def wisker(col):
    q1, q3 = np.percentile(col, [25, 75])
    iqr = q3 - q1
    lower_wisker = q1 - 1.5 * iqr
    upper_wisker = q3 + 1.5 * iqr
    return lower_wisker, upper_wisker

# %%
# implement function for Z-score method
def z_score(col, threshold=3):
    mean = col.mean()
    std_dev = col.std()
    lower_wisker = mean - threshold * std_dev
    upper_wisker = mean + threshold * std_dev
    return lower_wisker, upper_wisker

# %%
for col in covid.columns[1:]:
    if "Rate" not in col:
        lower_wisker, upper_wisker = wisker(covid[col])
        covid[col] = np.where(covid[col] < lower_wisker, lower_wisker, covid[col])
        covid[col] = np.where(covid[col] > upper_wisker, upper_wisker, covid[col])
    
    else:
        lower_wisker, upper_wisker = z_score(covid[col])
        covid[col] = np.where(covid[col] < lower_wisker, lower_wisker, covid[col])
        covid[col] = np.where(covid[col] > upper_wisker, upper_wisker, covid[col])

# %% [markdown]
# ### Verify outliers treatment

# %%
# set the number of rows and columns for the grid
rows, cols = 9, 4

# create subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
fig.tight_layout(pad=3.0)
fig.suptitle('Boxplot to check the outliers', fontsize=15, y=1.01)

# loop through each column and plot on a different subplot
for i, col in enumerate(covid.select_dtypes(include="number").columns):
    row_pos = i // cols
    col_pos = i % cols
    sns.boxplot(data=covid, x=col, ax=axes[row_pos, col_pos])
#     axes[row_pos, col_pos].set_title(col)

# remove any empty subplots
for j in range(i+1, rows*cols):
    fig.delaxes(axes[j // cols, j % cols])

plt.show()

# %% [markdown]
# # save the cleaned dataset

# %%
covid.to_csv("files/covid_dataset_cleaned.csv", index=False)

# %% [markdown]
# # Reshape Dataset for Visualization

# %% [markdown]
# ## Unipivot the clean dataset

# %%
# reading the new dataset
df = pd.read_csv("files/covid_dataset_cleaned.csv")

# %%
df.head()
# Out:
#          Date  Confirmed Cases Barisal  Case Rate Barisal  Deaths Barisal  \
# 0  2020-03-06                      1.0           7.000000             0.0
# 1  2020-03-08                      1.0          13.000000             0.0
# 2  2020-03-09                      0.0          13.631579             0.0
# 3  2020-03-18                      0.0          14.263158             1.0
# 4  2020-03-19                      0.0          14.894737             0.0
#
#    Death Rate Barisal  Confirmed Cases Chittagong  Case Rate Chittagong  \
# 0                 NaN                         0.0                   NaN
# 1                 NaN                         1.0             41.042423
# 2                 NaN                         2.0             33.000000
# 3           13.439422                         0.0             31.470588
# 4           13.439422                         0.0             29.941176
#
#    Deaths Chittagong  Death Rate Chittagong  Confirmed Cases Dhaka  ...  \
# 0                0.0                    NaN                    3.0  ...
# 1                0.0                    NaN                   55.0  ...
# 2                0.0                    NaN                    0.0  ...
# 3                1.0              13.439422                    0.0  ...
# 4                0.0              13.439422                    1.0  ...
#
#    Deaths Rangpur  Death Rate Rangpur  Confirmed Cases Sylhet  \
# 0             0.0                 NaN                     0.0
# 1             0.0                 NaN                     0.0
# 2             0.0                 NaN                     0.0
# 3             1.0           13.439422                     0.0
# 4             0.0           13.439422                     0.0
#
#    Case Rate Sylhet  Deaths Sylhet  Death Rate Sylhet  \
# 0               NaN            0.0                NaN
# 1               NaN            0.0                NaN
# 2               NaN            0.0                NaN
# 3               NaN            1.0          13.439422
# 4               NaN            0.0          13.439422
#
#    Confirmed Cases Allover Bangladesh  Case Rate Allover Bangladesh  \
# 0                                 0.0                           NaN
# 1                                 0.0                           NaN
# 2                                 0.0                           NaN
# 3                                 0.0                           NaN
# 4                                 0.0                           NaN
#
#    Deaths Allover Bangladesh  Death Rate Allover Bangladesh
# 0                        0.0                            NaN
# 1                        0.0                            NaN
# 2                        0.0                            NaN
# 3                        1.0                      13.439422
# 4                        0.0                      13.439422
#
# [5 rows x 37 columns]

# %%
# exclude 'Date' column for melting
value_vars = [col for col in df.columns if col != 'Date']

# %%
# Melt (unpivot)
df_long = df.melt(id_vars=['Date'], value_vars=value_vars, var_name='Metric', value_name='Value')

df_long.head()
# Out:
#          Date                   Metric  Value
# 0  2020-03-06  Confirmed Cases Barisal    1.0
# 1  2020-03-08  Confirmed Cases Barisal    1.0
# 2  2020-03-09  Confirmed Cases Barisal    0.0
# 3  2020-03-18  Confirmed Cases Barisal    0.0
# 4  2020-03-19  Confirmed Cases Barisal    0.0

# %%
# split 'Metric' into 'Region' and 'Type'
df_long[['Type', 'Region']] = df_long['Metric'].str.extract(r'(.+?)\s+(Barisal|Chittagong|Dhaka|Khulna\
                                                            |Mymensingh|Rajshahi|Rangpur|Sylhet|Allover Bangladesh)', expand=True)

# %%
# final clean up
df_long.drop(columns=['Metric'], inplace=True)

# reorder columns
df_long = df_long[['Date', 'Region', 'Type', 'Value']]

# %%
df_long.head()
# Out:
#          Date   Region             Type  Value
# 0  2020-03-06  Barisal  Confirmed Cases    1.0
# 1  2020-03-08  Barisal  Confirmed Cases    1.0
# 2  2020-03-09  Barisal  Confirmed Cases    0.0
# 3  2020-03-18  Barisal  Confirmed Cases    0.0
# 4  2020-03-19  Barisal  Confirmed Cases    0.0

# %%
# save the unipivoted dataframe to a new CSV file
df_long.to_csv("files/covid_dataset_unipivot.csv", index=False)

# %% [markdown]
# ## This NoteBook is created by Tshihab07, Dept. of Computer Science and Engineering
